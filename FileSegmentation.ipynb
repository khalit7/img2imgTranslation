# %%
import shutil
import os
import tensorflow as tf

# %%
# !ls  /root/.keras/datasets/img_align_celeba/img_align_celeba

# %%
source = "/content/drive/My Drive/grad_project/approach2/NoBackground_Dataset/val"
testing_path = "/content/drive/My Drive/grad_project/approach2/Dataset/rest_of_celebA"
files = os.listdir(source)
print(len(files))
# Out:
# 1275

# %%
'''files = os.listdir(source)
print(len(files))
destination = "/content/drive/My Drive/grad_project/approach2/NoBackground_Dataset/train"
for file in files[0:1992]:
	new_path = shutil.move(f"{source}/{file}", destination)
	#print(new_path)'''
# Out:
# 'files = os.listdir(source)\nprint(len(files))\ndestination = "/content/drive/My Drive/grad_project/approach2/NoBackground_Dataset/train"\nfor file in files[0:1992]:\n\tnew_path = shutil.move(f"{source}/{file}", destination)\n\t#print(new_path)'
